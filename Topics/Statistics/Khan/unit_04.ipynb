# %%
import khan_helper as kh
import numpy as np

# %%
test = kh.random_hist(10000, 100, 0, func=kh.mode)
# Out:
# 0.0
# [4.32120754 4.18029151 4.80459025 ... 5.03501116 2.27491505 3.31664281]

# %%
np.sort(test)
# Out:
# array([0.        , 0.54497691, 0.71107378, ..., 7.67647874, 7.7264431 ,
#        7.74676485])
